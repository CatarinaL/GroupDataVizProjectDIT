# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
data=pd.read_csv("aa.csv")

# %%
print(data)
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# 5     03/05/1915  01:00                                    Tienen, Belgium
# 6     09/03/1915  15:20                              Off Cuxhaven, Germany
# 7     07/28/1916    NaN                              Near Jambol, Bulgeria
# 8     09/24/1916  01:00                                Billericay, England
# 9     10/01/1916  23:45                               Potters Bar, England
# 10    11/21/1916    NaN                                     Mainz, Germany
# ...

# %%
print(data.head())
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# ...

# %%
Summ=data['Summary']

# %%
print(Summ)
# Out:
# 0       During a demonstration flight, a U.S. Army fly...
# 1       First U.S. dirigible Akron exploded just offsh...
# 2       The first fatal airplane accident in Canada oc...
# 3       The airship flew into a thunderstorm and encou...
# 4       Hydrogen gas which was being vented was sucked...
# 5       Crashed into trees while attempting to land af...
# 6       Exploded and burned near Neuwerk Island,  when...
# 7              Crashed near the Black Sea, cause unknown.
# 8       Shot down by British aircraft crashing in flames.
# 9       Shot down in flames by the British 39th Home D...
# 10                                    Crashed in a storm.
# 11      Shot down by British anti-aircraft fire and ai...
# 12                               Caught fire and crashed.
# 13      Struck by lightning and crashed into the Balti...
# 14      Crashed into the sea from an altitude of 3,000...
# 15                         Shot down by British aircraft.
# ...

# %%
data.drop('Ground', axis=1)##I thought once i dropped one it stayed dropped, which i was very wrong
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# 5     03/05/1915  01:00                                    Tienen, Belgium
# 6     09/03/1915  15:20                              Off Cuxhaven, Germany
# 7     07/28/1916    NaN                              Near Jambol, Bulgeria
# 8     09/24/1916  01:00                                Billericay, England
# 9     10/01/1916  23:45                               Potters Bar, England
# 10    11/21/1916    NaN                                     Mainz, Germany
# ...

# %%
data.drop('Registration', axis=1)
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# 5     03/05/1915  01:00                                    Tienen, Belgium
# 6     09/03/1915  15:20                              Off Cuxhaven, Germany
# 7     07/28/1916    NaN                              Near Jambol, Bulgeria
# 8     09/24/1916  01:00                                Billericay, England
# 9     10/01/1916  23:45                               Potters Bar, England
# 10    11/21/1916    NaN                                     Mainz, Germany
# ...

# %%
data.drop('Flight #', axis=1)
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# 5     03/05/1915  01:00                                    Tienen, Belgium
# 6     09/03/1915  15:20                              Off Cuxhaven, Germany
# 7     07/28/1916    NaN                              Near Jambol, Bulgeria
# 8     09/24/1916  01:00                                Billericay, England
# 9     10/01/1916  23:45                               Potters Bar, England
# 10    11/21/1916    NaN                                     Mainz, Germany
# ...

# %%
data.drop('Ground', axis=1, 'Registration', axis=1, 'Flight #', axis=1, 'cn/ln', axis=1)
# Out:
#   File "<ipython-input-11-672b5d037309>", line 1
#     data.drop('Ground', axis=1, 'Registration', axis=1, 'Flight #', axis=1, 'cn/ln', axis=1)
#                                ^
# SyntaxError: positional argument follows keyword argument

# %%
data.drop('Ground', axis=1)
data.drop('Registration', axis=1)
data.drop('Flight #', axis=1)
data.drop('cn/In', axis=1)
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# 5     03/05/1915  01:00                                    Tienen, Belgium
# 6     09/03/1915  15:20                              Off Cuxhaven, Germany
# 7     07/28/1916    NaN                              Near Jambol, Bulgeria
# 8     09/24/1916  01:00                                Billericay, England
# 9     10/01/1916  23:45                               Potters Bar, England
# 10    11/21/1916    NaN                                     Mainz, Germany
# ...

# %%
data.drop('Ground',axis=1, 'Flight #', axis=1, 'Registration', axis=1, 'cn/In', axis=1)
# Out:
#   File "<ipython-input-16-164baba008ec>", line 1
#     data.drop('Ground',axis=1, 'Flight #', axis=1, 'Registration', axis=1, 'cn/In', axis=1)
#                               ^
# SyntaxError: positional argument follows keyword argument

# %%
data.drop(columns=['Ground', 'Flight #','Registration', 'cn/In'])
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# 5     03/05/1915  01:00                                    Tienen, Belgium
# 6     09/03/1915  15:20                              Off Cuxhaven, Germany
# 7     07/28/1916    NaN                              Near Jambol, Bulgeria
# 8     09/24/1916  01:00                                Billericay, England
# 9     10/01/1916  23:45                               Potters Bar, England
# 10    11/21/1916    NaN                                     Mainz, Germany
# ...

# %%
print(data)
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# 5     03/05/1915  01:00                                    Tienen, Belgium
# 6     09/03/1915  15:20                              Off Cuxhaven, Germany
# 7     07/28/1916    NaN                              Near Jambol, Bulgeria
# 8     09/24/1916  01:00                                Billericay, England
# 9     10/01/1916  23:45                               Potters Bar, England
# 10    11/21/1916    NaN                                     Mainz, Germany
# ...

# %%
newdata=data.drop(columns=['Ground', 'Flight #','Registration', 'cn/In'])

# %%
print(new)
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# 5     03/05/1915  01:00                                    Tienen, Belgium
# 6     09/03/1915  15:20                              Off Cuxhaven, Germany
# 7     07/28/1916    NaN                              Near Jambol, Bulgeria
# 8     09/24/1916  01:00                                Billericay, England
# 9     10/01/1916  23:45                               Potters Bar, England
# 10    11/21/1916    NaN                                     Mainz, Germany
# ...

# %%
print(new['Fatalities'].notnull())
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26      False
# 27       True
# 28       True
# 29       True
#         ...
# 5238     True
# 5239     True
# 5240     True
# 5241     True
# 5242     True
# 5243     True
# 5244     True
# 5245     True
# 5246     True
# 5247     True
# 5248     True
# 5249     True
# 5250     True
# 5251     True
# 5252     True
# 5253     True
# 5254     True
# 5255     True
# 5256     True
# 5257     True
# 5258     True
# 5259     True
# 5260     True
# 5261     True
# 5262     True
# 5263     True
# 5264     True
# 5265     True
# 5266     True
# 5267     True
# ...

# %%
print(new['Aboard'].notnull())
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26      False
# 27       True
# 28       True
# 29       True
#         ...
# 5238     True
# 5239     True
# 5240     True
# 5241     True
# 5242     True
# 5243     True
# 5244     True
# 5245     True
# 5246     True
# 5247     True
# 5248     True
# 5249     True
# 5250     True
# 5251     True
# 5252     True
# 5253     True
# 5254     True
# 5255     True
# 5256     True
# 5257     True
# 5258     True
# 5259     True
# 5260     True
# 5261     True
# 5262     True
# 5263     True
# 5264     True
# 5265     True
# 5266     True
# 5267     True
# ...

# %%
print(new['Time'].notnull())
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
# 5        True
# 6        True
# 7       False
# 8        True
# 9        True
# 10      False
# 11       True
# 12      False
# 13      False
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19      False
# 20       True
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 5238     True
# 5239     True
# 5240     True
# 5241     True
# 5242     True
# 5243     True
# 5244     True
# 5245     True
# 5246     True
# 5247     True
# 5248     True
# 5249     True
# 5250     True
# 5251     True
# 5252     True
# 5253     True
# 5254     True
# 5255     True
# 5256     True
# 5257     True
# 5258     True
# 5259     True
# 5260     True
# 5261     True
# 5262     True
# 5263     True
# 5264    False
# 5265     True
# 5266     True
# 5267    False
# ...

# %%
new=print(new['Time'].dropna())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-4860263d2a6e> in <module>
# ----> 1 new=print(new['Time'].dropna())
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
# ...

# %%
print(new)
# Out:
# 0         17:18
# 1         06:30
# 3         18:30
# 4         10:30
# 5         01:00
# 6         15:20
# 8         01:00
# 9         23:45
# 11        23:45
# 14        05:15
# 15        08:45
# 16        07:00
# 17        07:45
# 18        21:30
# 20        10:00
# 55        17:40
# 80        02:30
# 96        05:30
# 108       13:15
# 119       08:30
# 123       10:00
# 162       10:00
# 163       08:00
# 175       09:18
# 190     c: 1:00
# 198       07:00
# 208       18:23
# 210       17:30
# 213     c:17:00
# 221       02:05
#          ...
# 5236      18:40
# 5237      11:00
# 5238      11:35
# 5239      10:32
# 5240      17:00
# 5241      12:13
# 5242      06:25
# 5243      16:40
# 5244      15:30
# 5245      15:06
# 5246      14:00
# 5247      06:30
# 5248      22:17
# 5249      16:05
# 5250      04:10
# 5251      10:31
# 5252      05:40
# 5253      09:48
# 5254      14:28
# 5255      06:48
# 5256      14:00
# 5257      12:30
# 5258      07:00
# 5259      10:30
# ...

# %%
print(new)
# Out:
# 0         17:18
# 1         06:30
# 3         18:30
# 4         10:30
# 5         01:00
# 6         15:20
# 8         01:00
# 9         23:45
# 11        23:45
# 14        05:15
# 15        08:45
# 16        07:00
# 17        07:45
# 18        21:30
# 20        10:00
# 55        17:40
# 80        02:30
# 96        05:30
# 108       13:15
# 119       08:30
# 123       10:00
# 162       10:00
# 163       08:00
# 175       09:18
# 190     c: 1:00
# 198       07:00
# 208       18:23
# 210       17:30
# 213     c:17:00
# 221       02:05
#          ...
# 5236      18:40
# 5237      11:00
# 5238      11:35
# 5239      10:32
# 5240      17:00
# 5241      12:13
# 5242      06:25
# 5243      16:40
# 5244      15:30
# 5245      15:06
# 5246      14:00
# 5247      06:30
# 5248      22:17
# 5249      16:05
# 5250      04:10
# 5251      10:31
# 5252      05:40
# 5253      09:48
# 5254      14:28
# 5255      06:48
# 5256      14:00
# 5257      12:30
# 5258      07:00
# 5259      10:30
# ...

# %%
print(newdata)
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# 5     03/05/1915  01:00                                    Tienen, Belgium
# 6     09/03/1915  15:20                              Off Cuxhaven, Germany
# 7     07/28/1916    NaN                              Near Jambol, Bulgeria
# 8     09/24/1916  01:00                                Billericay, England
# 9     10/01/1916  23:45                               Potters Bar, England
# 10    11/21/1916    NaN                                     Mainz, Germany
# ...

# %%
newdata.dropna()
# Out:
#             Date     Time                                           Location  \
# 0     09/17/1908    17:18                                Fort Myer, Virginia
# 1     07/12/1912    06:30                            AtlantiCity, New Jersey
# 80    12/23/1923    02:30                         Over the Mediterranean Sea
# 96    09/03/1925    05:30                                     Caldwell, Ohio
# 119   08/22/1927    08:30                                 Sevenoaks, England
# 123   09/23/1927    10:00                                   Schleiz, Germany
# 162   12/01/1928    10:00                                        Spur, Texas
# 175   03/30/1929    09:18                          Near Beaumont, California
# 190   09/03/1929  c: 1:00                             Mt. Taylor, New Mexico
# 198   11/04/1929    07:00                           Cerro del Carbon, Mexico
# 208   01/19/1930    18:23                              Oceanside, California
# ...

# %%
plt.bar('Location', width=0.4, align='center', height= 5)
# Out:
# <BarContainer object of 1 artists>

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter('Date', 'Time')
plt.show()

# %%
plt.show()

# %%
plt.scatter("Date", "Location")

# %%
import plotly.figure_factory as ff
import plotly.plotly as py
import plotly.graph_objs as go

d=[go.Scatter(x=newdata.Date, y=newdata.Location)]
py.iplot(d, filename = 'clean.csv')
# Out:
# Aw, snap! We didn't get a username with your request.
#
# Don't have an account? https://plot.ly/api_signup
#
# Questions? accounts@plot.ly
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-67-ddb1afa2bc24> in <module>
#       4
#       5 d=[go.Scatter(x=newdata.Date, y=newdata.Location)]
# ----> 6 py.iplot(d, filename = 'clean.csv')
#
# ~/anaconda3/lib/python3.7/site-packages/plotly/plotly/plotly.py in iplot(figure_or_data, **plot_options)
#     186         embed_options['height'] = str(embed_options['height']) + 'px'
#     187
# --> 188     return tools.embed(url, **embed_options)
#     189
#     190
#
# ~/anaconda3/lib/python3.7/site-packages/plotly/tools.py in embed(file_owner_or_url, file_id, width, height)
#     399         else:
#     400             url = file_owner_or_url
# --> 401         return PlotlyDisplay(url, width, height)
#     402     else:
# ...

# %%
x = newdata.Time
y = newdata.Location
plt.bar(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-cfe40543cb26> in <module>
#       1 x = newdata.Time
#       2 y = newdata.Location
# ----> 3 plt.bar(x, y)
#       4 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2457     return gca().bar(
#    2458         x, height, width=width, bottom=bottom, align=align,
# -> 2459         **({"data": data} if data is not None else {}), **kwargs)
#    2460
#    2461
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...

# %%
time = newdata['Time']
location = newdata['Location']
plt.scatter(time, location, edgecolors = 'r')
plt.xlabel = ('Location')
plt.ylabel = ('Time')
plt.title('Location and corresponding Times')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-df18fe4dc79a> in <module>
#       1 time = newdata['Time']
#       2 location = newdata['Location']
# ----> 3 plt.scatter(time, location, edgecolors = 'r')
#       4 plt.xlabel = ('Location')
#       5 plt.ylabel = ('Time')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
newdata.isnan()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-2b5953173930> in <module>
# ----> 1 newdata.isnan()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isnan'

# %%
newdata.isNaN()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-41b906c37158> in <module>
# ----> 1 newdata.isNaN()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isNaN'

# %%
newdata = newdata[newdata.isnull().any(axis=1)]
print(newdata)
# Out:
#             Date   Time                                     Location  \
# 2     08/06/1913    NaN           Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                           Over the North Sea
# 4     10/17/1913  10:30                   Near Johannisthal, Germany
# 5     03/05/1915  01:00                              Tienen, Belgium
# 6     09/03/1915  15:20                        Off Cuxhaven, Germany
# 7     07/28/1916    NaN                        Near Jambol, Bulgeria
# 8     09/24/1916  01:00                          Billericay, England
# 9     10/01/1916  23:45                         Potters Bar, England
# 10    11/21/1916    NaN                               Mainz, Germany
# 11    11/28/1916  23:45                 Off West Hartlepool, England
# 12    03/04/1917    NaN                           Near Gent, Belgium
# 13    03/30/1917    NaN                         Off Northern Germany
# 14    05/14/1917  05:15                 Near Texel Island, North Sea
# ...

# %%
date = newdata['Date']
location = newdata['Location']
plt.scatter(date, location, edgecolors = 'r')
plt.xlabel = 'Location'
plt.ylabel = 'Date'
plt.title = 'Location with corresponding date'
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-85d22c12834f> in <module>
#       1 date = newdata['Date']
#       2 location = newdata['Location']
# ----> 3 plt.scatter(date, location, edgecolors = 'r')
#       4 plt.xlabel = 'Location'
#       5 plt.ylabel = 'Date'
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
date = newdata['Date']
location = newdata['Location']
plt.scatter(date, location, edgecolors = 'r')
plt.xlabel = 'Location'
plt.ylabel = 'Date'
plt.title = 'Location with corresponding date'
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-5bd5923cf9ab> in <module>
#       1
# ----> 2 date = newdata(int['Date'])
#       3 location = newdata['Location']
#       4 plt.scatter(date, location, edgecolors = 'r')
#       5 plt.xlabel = 'Location'
#
# TypeError: 'type' object is not subscriptable

# %%
newdata1 = newdata.drop('NaN', axis = 0)
print(newdata)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-d448a5e389bd> in <module>
# ----> 1 newdata1 = newdata.drop('NaN', axis = 0)
#       2 print(newdata)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
aboard = newdata['Aboard']
fatalities = newdata['Fatalities']
plt.xlabel = 'Aboard'
plt.ylabel = 'Fatalities'
plt.title = 'Fatalities'
plt.scatter(aboard, fatalities, edgecolors = 'r')
plt.show()

# %%
aboard = newdata['Aboard']
fatalities = newdata['Fatalities']
plt.hist(aboard, fatalities)
plt.xlabel = 'Aboard'
plt.ylabel = 'Fatalities'
plt.title = 'Fatalities'
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-b16efc9d1e94> in <module>
#       1 aboard = newdata['Aboard']
#       2 fatalities = newdata['Fatalities']
# ----> 3 plt.hist(aboard, fatalities)
#       4 plt.xlabel = 'Aboard'
#       5 plt.ylabel = 'Fatalities'
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2659         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2660         color=color, label=label, stacked=stacked, normed=normed,
# -> 2661         **({"data": data} if data is not None else {}), **kwargs)
#    2662
#    2663
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
location = newdata['Location']
fatalities = newdata['Fatalities']
plt.bar(aboard, location, align = 'center')
plt.xlabel = 'Location'
plt.ylabel = 'Fatalities'
plt.title = 'Fatalities'
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-7efa89f21d1a> in <module>
#       1 location = newdata['Location']
#       2 fatalities = newdata['Fatalities']
# ----> 3 plt.bar(aboard, location, align = 'center')
#       4 plt.xlabel = 'Location'
#       5 plt.ylabel = 'Fatalities'
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2457     return gca().bar(
#    2458         x, height, width=width, bottom=bottom, align=align,
# -> 2459         **({"data": data} if data is not None else {}), **kwargs)
#    2460
#    2461
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# ...

# %%
check_nulls("Locations")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-1fcf678326ae> in <module>
# ----> 1 check_nulls("Locations")
#
# NameError: name 'check_nulls' is not defined

# %%
newdata['Locations'].isnull()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Locations'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-0f794f1d4d21> in <module>
# ----> 1 newdata['Locations'].isnull()
#
# ...
